# %%
import pandas as pd

# %%
df = pd.read_excel('/home/ai_car/AthenaBow/data/import mafc/debt_reminder_20210906_091941.xls')

# %%
df
# Out:
#                     CUSTOMER  AGREEMENTID                PRODUCT  \
# 0              TRẦN KIM THẮM      1443965          TOPUP - XSELL
# 1        NGUYỄN THỊ HOÀNG VY      1486701              Cash Loan
# 2                LÊ THỊ HIỀN      1489660              Cash Loan
# 3             TRẦN ĐĂNG KHẨN      1492817              Cash Loan
# 4              TRẦN VĂN KIÊN      2351109  CONSUMER DURABLE LOAN
# ...                      ...          ...                    ...
# 5468  NGUYỄN THÁI THẢO SƯƠNG       498175          TOPUP - XSELL
# 5469     PHẠM THỊ THẢO TRANG       508164              Cash Loan
# 5470     NGUYỄN THỊ TỐ HUYỀN       558768          TOPUP - XSELL
# 5471   NGUYỄN THỊ DIỄM TRINH       540011              Cash Loan
# 5472            LÊ LONG TOÀN       709746              Cash Loan
#
#       AMOUNT_FINANCE  TENURE  DUEDAY  CURRES_PHONE  MAX_DPD  MOB  \
# 0           13715000      30       8     977248204        0   15
# ...

# %%
pd.read_excel('/home/ai_car/AthenaBow/data/export mafc/debt_rescheduling_qc_20210929.xlsx')
# Out:
#        STT    CallID  Số khách hàng     Hotline        Thời điểm gọi  \
# 0        1  10413873      374155635  11291025.0  2021-09-29 09:00:08
# 1        1  10413873      374155635  11291025.0  2021-09-29 09:00:08
# 2        1  10413873      374155635  11291025.0  2021-09-29 09:00:08
# 3        2  10413876      852077779  11291025.0  2021-09-29 09:00:09
# 4        2  10413876      852077779  11291025.0  2021-09-29 09:00:09
# ...    ...       ...            ...         ...                  ...
# 5964  3054  10416368      907669146         NaN  2021-09-29 17:50:52
# 5965  3055  10416578      949953726         NaN  2021-09-29 18:34:32
# 5966  3056  10416684      888058180         NaN  2021-09-29 18:56:55
# 5967  3057  10416919      346323385         NaN  2021-09-29 19:46:03
# 5968  3058  10416988      941681031         NaN  2021-09-29 19:58:46
#
#      Thời lượng gọi Trạng thái          Mã tổng đài Mã kết thúc bot  \
# 0          00:00:29   Nghe máy  VOICEMAIL_DETECTION          SILENT
# ...
